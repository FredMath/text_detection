# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.core import *
from pathlib2 import Path
import json
import pandas as pd
import coco_text
import skimage.io as io
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
Path().absolute()
# Out:
# PosixPath('/home/paperspace/sceneText/nbs')

# %%
path_coco = Path('/home/paperspace/sceneText/data/coco')

# %%
img_dir = Path('/home/paperspace/sceneText/data/coco/images/train2014/')
annotations = Path('/home/paperspace/sceneText/data/coco/annotations/COCO_Text.json')

# %%
annotations
# Out:
# PosixPath('/home/paperspace/sceneText/data/coco/annotations/COCO_Text.json')

# %%
ct_anno = coco_text.COCO_Text(annotations)
# Out:
# loading annotations into memory...
# 0:00:01.992127
# creating index...
# index created!

# %%
ct_anno.info()
# Out:
# url: http://vision.cornell.edu/se3/coco-text/
# date_created: 2017-03-28
# version: 1.4
# description: This is 1.4 version of the 2017 COCO-Text dataset.
# author: COCO-Text group

# %%
imgs = ct_anno.getImgIds(imgIds=ct_anno.train) 
#catIds=[('legibility','legible'),('class','machine printed')])

# %%
anns = ct_anno.getAnnIds(imgIds=ct_anno.train) 
                        #catIds=[('legibility','legible'),('class','machine printed')], 
                        #areaRng=[0,200])

# %%
# get all images containing at least one instance of legible text
imgIds = ct_anno.getImgIds(imgIds=ct_anno.train, catIds=[('legibility','legible')])
# pick one at random
img = ct_anno.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]

# %%
dataType = 'train2014'


I = io.imread('%s/images/%s/%s'%(path_coco,dataType,img['file_name']))
print('%s/images/%s/%s'%(path_coco,dataType,img['file_name']))
plt.figure()
plt.imshow(I)
# Out:
# /home/paperspace/sceneText/data/coco/images/train2014/COCO_train2014_000000205707.jpg

# %%
plt.imshow(I)
annIds = ct_anno.getAnnIds(imgIds=img['id'])
anns = ct_anno.loadAnns(annIds)
ct_anno.showAnns(anns)

# %%
img
# Out:
# {'width': 640,
#  'file_name': 'COCO_train2014_000000205707.jpg',
#  'set': 'train',
#  'id': 205707,
#  'height': 427}

# %%
anns
# Out:
# [{'polygon': [487.089599609375,
#    353.1651802062988,
#    627.839599609375,
#    353.1651802062988,
#    627.839599609375,
#    408.5847587585449,
#    487.089599609375,
#    408.5847587585449],
#   'language': 'english',
#   'area': 7800.305681228638,
#   'id': 1214441,
#   'utf8_string': 'PHOTOGRAPHY',
#   'image_id': 205707,
#   'bbox': [487.089599609375, 353.1651802062988, 140.75, 55.419578552246094],
#   'legibility': 'legible',
#   'class': 'machine printed'},
#  {'polygon': [286.52027027027026,
#    105.93924050632911,
#    314.6283783783784,
#    105.93924050632911,
#    314.6283783783784,
#    161.07088607594937,
#    286.52027027027026,
#    161.07088607594937],
#   'language': 'english',
#   'area': 1549.6462538487856,
#   'id': 1076693,
#   'utf8_string': 'IISIS',
#   'image_id': 205707,
#   'bbox': [286.52027027027026,
#    105.93924050632911,
#    28.108108108108105,
#    55.13164556962026],
#   'legibility': 'legible',
#   'class': 'machine printed'},
#  {'polygon': [293.61505719828745,
#    202.5086589905324,
#    316.08441764784595,
#    202.5086589905324,
#    316.08441764784595,
#    216.21508363825154,
#    293.61505719828745,
#    216.21508363825154],
#   'language': 'english',
#   'area': 307.9745958843139,
#   'id': 1214443,
#   'utf8_string': 'lou',
#   'image_id': 205707,
#   'bbox': [293.61505719828745,
#    202.5086589905324,
#    22.46936044955848,
#    13.706424647719137],
#   'legibility': 'legible',
#   'class': 'machine printed'},
#  {'polygon': [425.67431598795116,
#    367.14203759629834,
#    477.9765688259647,
#    367.14203759629834,
#    477.9765688259647,
#    404.7481749188913,
#    425.67431598795116,
#    404.7481749188913],
#   'language': 'english',
#   'area': 1966.8857025073182,
#   'id': 1214442,
#   'utf8_string': 'RP',
#   'image_id': 205707,
#   'bbox': [425.67431598795116,
#    367.14203759629834,
#    52.302252838013565,
#    37.606137322593014],
#   'legibility': 'legible',
#   'class': 'machine printed'},
#  {'polygon': [323.7625786039356,
#    215.65592583570486,
#    332.36610077046794,
#    212.57753646903495,
#    337.3969672945019,
#    226.6378668889045,
#    328.79344512796956,
#    229.71625625557442],
#   'language': 'english',
#   'area': 233.6759672283788,
#   'id': 1214444,
#   'utf8_string': '7',
#   'image_id': 205707,
#   'bbox': [323.7625786039356,
#    212.57753646903495,
#    13.634388690566311,
#    17.13871978653947],
#   'legibility': 'legible',
#   'class': 'machine printed'}]

# %%
train_imgs = ct_anno.loadImgs(ct_anno.train)

# %%
len(train_imgs)
# Out:
# 43686

# %%
train_imgs[0]
# Out:
# {'width': 612,
#  'file_name': 'COCO_train2014_000000378466.jpg',
#  'set': 'train',
#  'id': 378466,
#  'height': 612}

# %%
train_anno_ids = ct_anno.getAnnIds(ct_anno.train)

# %%
len(train_anno_ids)
# Out:
# 118309

# %%
type(train_anno_ids[0])
# Out:
# int

# %%
train_annos = ct_anno.loadAnns(train_anno_ids)

# %%
len(train_annos)
# Out:
# 118309

# %%
train_annos[2]['bbox']
# Out:
# [108, 105, 138, 37]

# %%
sz = 224

images = train_imgs
lbl_bbox = pd.DataFrame()


for im in range(len(images)):
    img_bbox = train_annos[im]['bbox']
    img_id = train_imgs[im]['id']
    #print(img_bbox)
    lbl_bbox = lbl_bbox.append(pd.DataFrame({'Image_id: ' : img_id, 'bbox: ' : img_bbox}), ignore_index=True)
    #lbl_bbox = pd.concat({'Image_id: ' : img_id}, {'bbox: ' : img_bbox})

# %%
lbl_bbox.head(10)
# Out:
#    Image_id:       bbox:
# 0      378466  212.352941
# 1      378466  108.670886
# 2      378466   25.815126
# 3      378466   17.215190
# 4      287140  617.865546
# 5      287140  179.683544
# 6      287140   21.134454
# 7      287140   43.037975
# 8      332243  108.000000
# 9      332243  105.000000

# %%
from fastai.vision import *

# %%
dsl = ImageDataBunch
